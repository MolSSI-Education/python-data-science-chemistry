# %% [markdown]
# Session 2 Homework Solution
# ========================
#
# ## Exercise 1
#
# In the first class, we examined a dataset containing molecular descriptors and the results from the ESOL solubility model. In this homework, we are going to use the `tabula` library to extract a table from the associated paper. In your `pdf` folder, you have a file called `Delaney_paper.pdf`. Your task for this homework is to pull information from table 4 and create plots using seaborn showing  the correlation between the various solubility models and the experimental values.
#
# Using the file `pdfs/Delaney_paper.pdf` and `tabula-py`, read in the data from Table 4. Save this file in your data folder as `delaney_table4.csv`.

# %%
import tabula
import pandas as pd
import seaborn as sns

# %%
import tabula

table1 = tabula.read_pdf('pdfs/Delaney_paper.pdf', pages=[4])
# Out:
# Got stderr: May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Roman
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Bold
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Italic
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-BoldItalic
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica-Bold
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica-Oblique
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica-BoldOblique
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Courier
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Courier-Bold
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Courier-Oblique
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Courier-BoldOblique
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Roman
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Bold
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Italic
# May 05, 2021 4:34:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Symbol
# May 05, 2021 4:34:18 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Roman
# May 05, 2021 4:34:18 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Bold
# May 05, 2021 4:34:18 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times-Italic
# May 05, 2021 4:34:18 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Symbol

# %%
df = table1[0]

# %%
df.head()
# Out:
#     Unnamed: 0  Unnamed: 1 experimental Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0  common name     CAS no.   values4,28       ESOL       Liu7  Huuskonen6
# 1   antipyrine     60-80-0        -0.56      -1.79      -1.41       -1.29
# 2      aspirin     50-78-2        -1.72      -1.98       -2.1       -1.69
# 3     atrazine  191-2 24-9        -3.85      -2.95      -1.51       -3.51
# 4   benzocaine     9-409-7        -2.32      -2.38      -1.45       -1.79
#
#   Unnamed: 5 Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0     Kuhne3   Wegne1r1  Gasteiger 10     Tetk8o        GSE
# 1       -1.9      -1.74         -1.31      -0.89      -0.56
# 2      -1.93      -1.81         -1.87      -1.81      -1.62
# 3      -3.95      -2.82         -3.83       -3.7       -3.5
# 4        NaN      -2.05         -2.19      -1.63      -2.06

# %%
df.to_csv("data/delaney_table4.csv", index=False)

# %% [markdown]
# ## Exercise 2
#
# Read in your saved data and clean the table using pandas.
#
# - Rename the columns to have easy and descriptive names.
# - Use `pd.to_numeric` with the appropriate options to cast columns to floats.
# - Drop rows or columns if necessary.
#
# Your dataframe should have the following column names before you save it:
#
# ```
# ['common name', 'CAS no.', 'experimental values', 'ESOL', 'Liu',
#        'Huuskonen', 'Kuhne', 'Wegner', 'Gasteiger', 'Tetko', 'GSE']
# ```
#
# Save your cleaned dataframe as `delaney_table4_clean.csv`

# %%
df = pd.read_csv("data/delaney_table4.csv")

df.head()
# Out:
#     Unnamed: 0  Unnamed: 1 experimental Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0  common name     CAS no.   values4,28       ESOL       Liu7  Huuskonen6
# 1   antipyrine     60-80-0        -0.56      -1.79      -1.41       -1.29
# 2      aspirin     50-78-2        -1.72      -1.98       -2.1       -1.69
# 3     atrazine  191-2 24-9        -3.85      -2.95      -1.51       -3.51
# 4   benzocaine     9-409-7        -2.32      -2.38      -1.45       -1.79
#
#   Unnamed: 5 Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0     Kuhne3   Wegne1r1  Gasteiger 10     Tetk8o        GSE
# 1       -1.9      -1.74         -1.31      -0.89      -0.56
# 2      -1.93      -1.81         -1.87      -1.81      -1.62
# 3      -3.95      -2.82         -3.83       -3.7       -3.5
# 4        NaN      -2.05         -2.19      -1.63      -2.06

# %%
df.columns = ['common name', 'CAS no.', 'experimental values', 'ESOL', 'Liu',
       'Huuskonen', 'Kuhne', 'Wegner', 'Gasteiger', 'Tetko', 'GSE']

# %%
df.drop(index=0, inplace=True)

# %%
df.head()
# Out:
#   common name     CAS no. experimental values   ESOL    Liu Huuskonen  Kuhne  \
# 1  antipyrine     60-80-0               -0.56  -1.79  -1.41     -1.29   -1.9
# 2     aspirin     50-78-2               -1.72  -1.98   -2.1     -1.69  -1.93
# 3    atrazine  191-2 24-9               -3.85  -2.95  -1.51     -3.51  -3.95
# 4  benzocaine     9-409-7               -2.32  -2.38  -1.45     -1.79    NaN
# 5   chlordane    5-7 74-9               -6.86  -5.88  -7.32     -7.29  -6.51
#
#   Wegner Gasteiger  Tetko    GSE
# 1  -1.74     -1.31  -0.89  -0.56
# 2  -1.81     -1.87  -1.81  -1.62
# 3  -2.82     -3.83   -3.7   -3.5
# 4  -2.05     -2.19  -1.63  -2.06
# 5  -6.47     -7.66  -7.23   -5.3

# %%
df.iloc[:, 2:] = df.iloc[:, 2:].apply(pd.to_numeric, axis=1, errors="coerce")

# %%
df.to_csv("data/delaney_table4_clean.csv", index=False)

# %% [markdown]
# ## Exercise 3
#
# Use seaborn `lmplot` to create a plot showing `experimental values` vs each of the models. You should have one plot per model. Create a plot which has two columns per row.

# %%
df2 = pd.read_csv("data/delaney_table4_clean.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   common name          21 non-null     object
#  1   CAS no.              21 non-null     object
#  2   experimental values  21 non-null     float64
#  3   ESOL                 21 non-null     float64
#  4   Liu                  21 non-null     float64
#  5   Huuskonen            21 non-null     float64
#  6   Kuhne                19 non-null     float64
#  7   Wegner               21 non-null     float64
#  8   Gasteiger            21 non-null     float64
#  9   Tetko                21 non-null     float64
#  10  GSE                  19 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.9+ KB

# %%
df_melt = pd.melt(df2, id_vars="experimental values", 
                  value_vars=["ESOL", "Liu", "Huuskonen", "Kuhne", "Wegner", "Gasteiger", "Tetko", "GSE"])

# %%
df_melt
# Out:
#      experimental values variable  value
# 0                  -0.56     ESOL  -1.79
# 1                  -1.72     ESOL  -1.98
# 2                  -3.85     ESOL  -2.95
# 3                  -2.32     ESOL  -2.38
# 4                  -6.86     ESOL  -5.88
# ..                   ...      ...    ...
# 163                -2.90      GSE  -4.52
# 164                -3.99      GSE  -4.28
# 165                -2.47      GSE  -1.93
# 166                -4.09      GSE  -4.02
# 167                -1.39      GSE  -1.91
#
# [168 rows x 3 columns]

# %%
sns.set(font_scale=1.5)
g = sns.lmplot(data = df_melt, y="experimental values", x="value", 
               col="variable", col_wrap=2)
g.tight_layout()
